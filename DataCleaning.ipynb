# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/Users/jay/Desktop/Spring 2023/ML/My projects/glassdoor_jobs.csv')
data.columns
# data.describe()
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %% [markdown]
# ## Salary Estimate Column Cleaning

# %%
data = data[data['Salary Estimate'] != '-1']
data
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
# removing the (Glassdoor est) from the Salary Estimate Column

salary = data['Salary Estimate'].apply(lambda x: x.split('(')[0])

# removing k and $ signs and replacing them with space

rmv_k = salary.apply(lambda x: x.replace('$','').replace('K','')) 

# salary

# %%
data['hourly'] = data['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
data['employer_provided'] = data['Salary Estimate'].apply(lambda x: 1 if 'employer provided' in x.lower() else 0)
data
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
# removing per hour and employee provided from Salary estimate
rmv_hr = rmv_k.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))
data['min_salary'] = rmv_hr.apply(lambda x: int(x.split('-')[0]))
data['max_salary'] = rmv_hr.apply(lambda x: int(x.split('-')[1]))
data['avg_salary'] = (data.min_salary + data.max_salary)/2
data
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# ## Company Name Cleaning

# %%
data['comapany_txt'] = data.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3],axis=1)
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# ## Get state from the location column

# %%
data['state'] = data['Location'].apply(lambda x: x.split(',')[1])
data.state.value_counts()
# checkinf if the headquarters and job location are in the same state

data['same_state'] = data.apply(lambda x : 1 if x['state'] == x['Headquarters'] else 0,axis=1)
data
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
# age of the company

data['age'] = data['Founded'].apply(lambda x: x if x < 1 else 2023 - x )
data
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# ## Job Description

# %%
data['python_yn'] = data['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
data.python_yn.value_counts()
# Out:
# 1    392
# 0    350
# Name: python_yn, dtype: int64

# %%
data['studio_yn'] = data['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() else 0)
data.studio_yn.value_counts()
# Out:
# 0    741
# 1      1
# Name: studio_yn, dtype: int64

# %%
data['spark_yn'] = data['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
data.spark_yn.value_counts()
# Out:
# 0    575
# 1    167
# Name: spark_yn, dtype: int64

# %%
data['sql_yn'] = data['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)
data.sql_yn.value_counts()
# Out:
# 1    380
# 0    362
# Name: sql_yn, dtype: int64

# %%
data['aws_yn'] = data['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
data.aws_yn.value_counts()
# Out:
# 0    566
# 1    176
# Name: aws_yn, dtype: int64

# %%
data['azure_yn'] = data['Job Description'].apply(lambda x: 1 if 'azure' in x.lower() else 0)
data.azure_yn.value_counts()
# Out:
# 0    688
# 1     54
# Name: azure_yn, dtype: int64

# %%
data['excel_yn'] = data['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
data.excel_yn.value_counts()
# Out:
# 1    388
# 0    354
# Name: excel_yn, dtype: int64

# %%
data['ml_yn'] = data['Job Description'].apply(lambda x: 1 if 'machine learning' in x.lower() or 'ml' in x.lower() else 0)
data.ml_yn.value_counts()
# Out:
# 1    372
# 0    370
# Name: ml_yn, dtype: int64

# %%
data['scikit_yn'] = data['Job Description'].apply(lambda x: 1 if 'scikit learn' in x.lower() or 'scikit' in x.lower() else 0)
data.scikit_yn.value_counts()
# Out:
# 0    688
# 1     54
# Name: scikit_yn, dtype: int64

# %%
del data['Unnamed: 0']

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'comapany_txt', 'state', 'same_state', 'age', 'python_yn', 'studio',
#        'studio_yn', 'spark_yn', 'sql_yn', 'aws_yn', 'azure_yn', 'excel_yn',
#        'ml_yn', 'scikit_yn'],
#       dtype='object')

# %%
data.to_csv('salaryData_cleaned.csv',index=False)

# %%
sal_data = pd.read_csv('/Users/jay/Desktop/Spring 2023/ML/My projects/salaryData_cleaned.csv')
sal_data
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...
